# %% [markdown]
# # Games data
#
# This file takes the player_seasons data and the player_matches_data, aggregates them, and creates a new dataframe in a form that can be easily input to a model

# %%
import pandas as pd
import numpy as np

# %%
NUM_PLAYERS_CONSIDERED_PER_TEAM = 7
ROLLING_GAMES_WINDOW = 5 # must match player_matches_data (should clean this up, non-dup)
PLAYER_MATCHES_FILENAME = "../data/20100101_20191118_player_matches.csv"
PLAYER_SEASONS_FILENAME = "../data/2009_2019_player_seasons_unique.csv"

# %%
player_matches = pd.read_csv(PLAYER_MATCHES_FILENAME)
player_seasons = pd.read_csv(PLAYER_SEASONS_FILENAME)

# %%
recent_stats_suffix = "_l" + str(ROLLING_GAMES_WINDOW)
player_matches = player_matches.sort_values(by=['game_id', 'fp' + recent_stats_suffix], ascending=[True, False])

team_game_group = player_matches.groupby(by=['game_id', 'home_game'])
player_matches = team_game_group.head(NUM_PLAYERS_CONSIDERED_PER_TEAM).reset_index(drop=True)

# %%
stats = ['fgm', 'fga', '3pm', '3pa', 'ftm', 'fta', 'orb', 'drb', 'ast', 'stl', 'blk', 'tvr', 'pf', 'fp']
season_stats = ['player_id'] + [s + "_seas_avg" for s in stats]
recent_stats = [s + recent_stats_suffix for s in stats]

# %%
merge_season_fields = ['end_year'] + season_stats
to_merge_season_data = player_seasons[merge_season_fields]

# %%
merged_data = pd.merge(
    player_matches,
    to_merge_season_data,
    how='left',
    left_on=['player_id', 'season_start_year'],
    right_on = ['player_id', 'end_year']
).fillna(0)

# %%
y = ['fp']

all_data =  season_stats + recent_stats + y

# %%
per_game_df = pd.DataFrame()
game_group = merged_data.groupby('game_id')

for field in all_data:
    v = game_group.apply(lambda x: x[field].tolist())
    df = pd.DataFrame(v.tolist(), index=v.index).rename(columns=lambda x: x + 1).add_prefix(field + "_p").reset_index(drop=True)
    per_game_df = pd.concat([per_game_df, df], axis=1, sort=False)

# %%
per_game_df = per_game_df.fillna(0)

# %%
per_game_df
# Out:
#       player_id_p1 player_id_p2 player_id_p3 player_id_p4 player_id_p5  \
# 0        robinna01    horfoal01    johnsjo02    chandwi01    smithjo03
# 1        bryanko01    hawessp01    udrihbe01    gasolpa01    casspom01
# 2        flynnjo01    howardw01    anderry01    nelsoja01    lewisra02
# 3        wallara01     boshch01    allenra02    allento01    turkohe01
# 4        howardw01    anderry01    nelsoja01    lewisra02    barnema02
# 5        flynnjo01    jeffeal01     loveke01    ellinwa01    wilkida02
# 6         wadedw01    jacksst02    richaqu01    wallage01    hasleud01
# 7        westbru01    duranke01    bogutan01     reddmi01    maynoer01
# 8        jamesle01    harride01    lopezbr01    jianlyi01    varejan01
# 9         paulch01    arizatr01    okafoem01    hayesch01    lowryky01
# 10        nashst01     mayooj01    stoudam01    amundlo01      gayru01
# 11         roybr01    webstma02    ellismo01    millean02    randoan01
# 12       hawessp01    udrihbe01    casspom01    thompja02    nowitdi01
# 13       hilarne01    lawsoty01     okurme01    boozeca01    martike01
# 14       jamisan01    arenagi01    duncati01    masonro01    butleca01
# 15       jacksst02    jamesle01    wallage01    varejan01    onealsh01
# 16       hilarne01    lawsoty01    martike01    afflaar01    smithjr01
# 17       bryanko01    nowitdi01     odomla01    bynuman01    goodedr01
# 18       chandwi01    hibbero01     headlu01    gallida01    dunlemi02
# 19        boshch01    duncati01    masonro01     jackja01    bargnan01
# 20       westbru01    duranke01     rosede01     denglu01    gibsota01
# 21         roybr01    webstma02    millean02    howarju01    cunnida01
# 22        wadedw01    horfoal01    johnsjo02    smithjo03    richaqu01
# 23        paulch01     okurme01    boozeca01    okafoem01    willide01
# 24       jacksst02     rosede01    wallage01     denglu01    hinriki01
# 25        kiddja01    nowitdi01    terryja01    goodedr01    howarjo01
# 26       hilarne01    lawsoty01    ellismo01    martike01    randoan01
# 27       barnema02    howardw01    hibbero01     headlu01    nelsoja01
# 28       bryanko01    farmajo01     odomla01    arizatr01    hayesch01
# 29       bogutan01    harride01    lopezbr01    jianlyi01    ilyaser01
# ...            ...          ...          ...          ...          ...
# 12575    vucevni01    horfoal01    simmobe01    isaacjo01    harrito02
# 12576    lillada01    siakapa01    vanvlfr01    whiteha01    mccolcj01
# 12577    butleji01     loveke01    leoname01    adebaba01    dragigo01
# 12578    irvinky01    jokicni01    bartowi01    princta02    dinwisp01
# 12579    antetgi01    bledser01    lavinza01    cartewe01    satorto01
# 12580    georgpa01    willilo02    holidjr01    harremo01    redicjj01
# 12581    doncilu01    morrima03    porzikr01    barrerj01    randlju01
# 12582    youngtr01    rubiori01    bookede01    parkeja01    kaminfr01
# 12583    grahade01    drumman01    kennalu01    roziete01    griffbl01
# 12584    russeda01    walkeke02    tatumja01    brownja02    pascher01
# 12585    hardeja01    sabondo01    westbru01    tuckepj01     leaftj01
# 12586    davisan02    jamesle01    bogdabo01    hieldbu01    barneha02
# 12587    mitchdo01    goberru01    brookdi01    bogdabo02    crowdja01
# 12588    townska01     bealbr01    dienggo01    teaguje01    hachiru01
# 12589    embiijo01    simmobe01     paulch01    horfoal01    schrode01
# 12590    vucevni01    derozde01    aldrila01    gordoaa01    murrade01
# 12591    lavinza01    princta02    dinwisp01    satorto01    whiteco01
# 12592    doncilu01    siakapa01    vanvlfr01    porzikr01    anunoog01
# 12593    antetgi01    bledser01    sabondo01    warretj01    turnemy01
# 12594    youngtr01    georgpa01    willilo02    parkeja01    harremo01
# 12595    holidjr01    butleji01    adebaba01    favorde01    willike04
# 12596    hardeja01    townska01    teaguje01    covinro01    clemoch01
# 12597    morrima03    grahade01    roziete01    randlju01    barrerj01
# 12598    lillada01    aldrila01    whiteha01    mccolcj01    derozde01
# 12599    embiijo01    simmobe01    thomptr01     loveke01    harrito02
# 12600    youngtr01    jamesle01    davisan02    parkeja01    rondora01
# 12601    jokicni01    murraja01    crowdja01    jacksja02    millspa01
# 12602    holidjr01    redicjj01    pascher01    greendr01    willike04
# 12603     bealbr01    vucevni01    gordoaa01    fournev01    bryanth01
# 12604    walkeke02    bogdabo01    hieldbu01    brownja02    tatumja01
#
#       player_id_p6 player_id_p7 player_id_p8 player_id_p9 player_id_p10  ...  \
# 0        bibbymi01    gallida01    harrial01      leeda02     duhonch01  ...
# 1         odomla01    bynuman01    udokaim01    fishede01     rodrise01  ...
# 2        barnema02    cartevi01    jeffeal01     loveke01     ellinwa01  ...
# 3         jackja01    bargnan01    perkike01    houseed01     davisgl01  ...
# 4        cartevi01     rosede01     denglu01    gibsota01     salmojo01  ...
# 5        hibbero01     headlu01    watsoea01    mcrobjo01     dunlemi02  ...
# 6         diawbo01    augusdj01    feltora01    beaslmi01     onealje01  ...
# 7        ilyaser01    jennibr01    warriha01    sefolth01     ridnolu01  ...
# 8        onealsh01    douglch01    willima01    parkean01       leeco01  ...
# 9        brookaa01     westda01    battish01    brownde02     scolalu01  ...
# 10       randoza01    youngsa01    gasolma01    tinslja01     conlemi01  ...
# 11       maggeco01    howarju01    cunnida01    morroan01     curryst01  ...
# 12        kiddja01    goodedr01    evansty01    greendo01     terryja01  ...
# 13       willide01    afflaar01    smithjr01    millspa01     brewero02  ...
# 14       parketo01    blatcan01    jefferi01    ginobma01     boganke01  ...
# 15       willima01     diawbo01    augusdj01    feltora01     parkean01  ...
# 16       cartean01    brandel01    iversal01    carnero01     youngth01  ...
# 17       bareajo01    mariosh01    brownsh01    vujacsa01     farmajo01  ...
# 18        rushbr01    jonesda02    harrial01      leeda02     duhonch01  ...
# 19       parketo01    jefferi01    ginobma01    boganke01     banksma01  ...
# 20       maynoer01    salmojo01    hinriki01    sefolth01     collini01  ...
# 21       bayleje01    pendeje02    cambyma01    davisba01     kamanch01  ...
# 22       bibbymi01    hasleud01    beaslmi01    willima02     crawfja01  ...
# 23        westda01    millspa01    brewero02    kirilan01     brownde02  ...
# 24       gibsota01    feltora01     noahjo01    murraro01     thomaty01  ...
# 25       bareajo01    mariosh01    villach01    stuckro01     hamilri01  ...
# 26       maggeco01    afflaar01    smithjr01    morroan01     cartean01  ...
# 27       watsoea01    lewisra02    dunlemi02    jonesda02      rushbr01  ...
# 28       bynuman01    lowryky01    brookaa01    battish01     fishede01  ...
# 29       jennibr01    douglch01    warriha01    ridnolu01     mbahalu01  ...
# ...            ...          ...          ...          ...           ...  ...
# 12575    richajo01    gordoaa01    fournev01     netora01      rosste01  ...
# 12576    bouchch01     hoodro01    gasolma01    hezonma01     powelno01  ...
# 12577    sextoco01    herroty01     nunnke01    clarkjo01     robindu01  ...
# 12578    jordade01    harrijo01    millspa01    allenja01     harriga01  ...
# 12579    markkla01    lopezbr01     dunnkr01     hillge01     whiteco01  ...
# 12580    willike04    favorde01    mcgruro01    jacksfr01     zubaciv01  ...
# 12581    dotsoda01    poweldw01    marjabo01    smithde03     robinmi01  ...
# 12582    johnsca02    oubreke01    saricda01    reddica01     huntede01  ...
# 12583     rosede01    brownbr01     monkma01    morrima02     gallola01  ...
# 12584    burksal01    smartma01    greendr01    robingl02     kanteen01  ...
# 12585    bitadgo01    holidaa01    mcderdo01    holidju01     mccontj01  ...
# 12586    bjeline01    holmeri01    caldwke01    howardw01     kuzmaky01  ...
# 12587    jacksja02    moranja01    valanjo01    conlemi01     anderky01  ...
# 12588    bryanth01    covinro01    okogijo01    thomais02     browntr01  ...
# 12589    richajo01    gallida01    harrito02    gilgesh01     adamsst01  ...
# 12590    fournev01    millspa02    augusdj01     rosste01     forbebr01  ...
# 12591    jordade01    cartewe01    allenja01    markkla01      dunnkr01  ...
# 12592    gasolma01    holliro01    klebima01    brunsja01     curryse01  ...
# 12593     leaftj01    divindo01    lopezbr01    holidaa01     mcderdo01  ...
# 12594    huntede01    reddica01    harklma01    zubaciv01     jonesda03  ...
# 12595     nunnke01    alexani01    herroty01    olynyke01     mellini01  ...
# 12596    tuckepj01    laymaja01    vonleno01    mclembe01     culveja01  ...
# 12597     monkma01    ntilila01    zelleco01    washipj01     gibsota01  ...
# 12598      gayru01     hoodro01    hezonma01    forbebr01     millspa02  ...
# 12599    richajo01    sextoco01    horfoal01    garlada01     clarkjo01  ...
# 12600    mcgeeja01    huntede01    crabbal01    kuzmaky01     howardw01  ...
# 12601    moranja01    valanjo01    anderky01    clarkbr01     morrimo01  ...
# 12602    alexani01    burksal01    mooreet01    mellini01     bowmaky01  ...
# 12603    bertada01    wagnemo01    milescj01     rosste01     thomais02  ...
# 12604    smartma01    barneha02    bjeline01    holmeri01     kanteen01  ...
#
#       fp_p5 fp_p6 fp_p7 fp_p8  fp_p9  fp_p10  fp_p11  fp_p12  fp_p13  fp_p14
# 0      49.5  31.9  30.7  27.8   25.4    24.4    16.9    14.2    12.2    11.6
# 1      43.7  43.5  34.3  25.5   19.1    15.5    10.2    10.1     9.9     7.9
# 2      37.9  34.7  34.4  33.5   30.5    23.3    21.1    18.2    16.7    14.2
# 3      35.9  35.9  34.3  33.5   29.8    24.0    14.5    14.1    12.4    11.2
# 4      45.3  20.6  47.7  39.8   36.4    27.8    22.8    22.7    20.1    19.5
# 5      15.9  47.4  39.8  32.3   30.6    30.1    29.1    27.9    20.3    17.8
# 6      28.0  25.5  24.7  24.6   24.2    24.0    21.3    18.2    13.9    11.4
# 7      32.2  32.0  28.9  26.6   22.8    22.2    20.9    19.4    19.4    18.6
# 8      35.4  27.3  27.1  26.9   18.8    17.7    14.2    13.8     9.2     7.4
# 9      30.2  27.2  27.0  23.8   18.9    18.6    17.2    17.1    13.7     9.7
# 10     39.2  38.7  34.8  32.8   26.4    25.1    24.9    15.4    12.9    12.7
# 11     38.7  33.1  25.2  22.5   20.3    16.7    15.6     8.6     8.0     2.4
# 12     43.9  39.9  33.5  32.0   29.9    29.3    27.7    24.1    19.5     9.8
# 13     38.4  34.0  30.4  28.4   22.7    21.1    21.0    20.1    14.4    13.9
# 14     37.7  26.1  25.7  25.6   21.3    20.7    17.8    17.7    15.7     6.9
# 15     18.4  55.0  14.4  11.5   37.4    15.4    28.4    16.1    21.2    15.5
# 16     20.9  21.6  36.4  27.5   24.2    24.0    24.0    23.9    22.1    11.5
# 17     23.4  15.7  17.1  21.7   32.0    47.7    20.2    20.1    19.8    19.0
# 18     25.0  18.6  24.1  23.9   51.7    50.1    23.9    22.1    20.4    15.6
# 19     43.1  40.6  18.9  24.4   22.9    13.4    19.3    18.2    16.7    13.4
# 20     29.8  22.6  10.4  45.1   28.8    20.1    38.3    24.6    29.2    20.2
# 21     19.6  13.2  19.4  54.0   41.1    35.6    32.4    20.9    17.7    16.2
# 12601  47.1  26.4  32.0  19.8   30.5    21.4    31.3    27.8    30.9    32.6
# 12602  26.0  44.0  19.3  22.4   36.5    36.4    27.3    26.2    27.4    34.0
# 12603  32.2  42.1  24.1  37.5   29.3    26.5    27.1    32.6    16.2    22.3
# 12604  29.2  29.5  30.1  39.8   28.2    21.4    27.5    13.4    16.8    26.9
#
# [12605 rows x 420 columns]

# %%
path = "../data/games_" + str(NUM_PLAYERS_CONSIDERED_PER_TEAM) + "_players" + ".csv"
per_game_df.to_csv(path, index = False)

# %% [markdown]
# ## Duplicate the rows (for each game, each player gets to be player_1)

# %%
def swap_colums_orders(colnames, i, j):
    pi = "_p" + str(i)
    pj = "_p" + str(j)
    swapped_colnames = []
    for col in colnames :
        new_col = col
        if col.find(pi, len(col)-len(pi)) > -1:
            new_col = col.replace(pi, pj)
        if col.find(pj, len(col)-len(pj)) > -1:
            new_col = col.replace(pj, pi)
        swapped_colnames.append(new_col)
    return swapped_colnames
def swap_team_columns(colnames):
    swaped_teams = colnames
    for i in range(1,8):
        swaped_teams = swap_colums_orders(swaped_teams, i, 7+i)
    return swaped_teams

# %%
colnames_all = per_game_df.columns
all_per_game_df = per_game_df

for team in range(2) :
    for i in range(2+7*team, 8+7*team):
        temps_df = per_game_df[swap_colums_orders(colnames_all, 1+7*team, i)]
        if team==1:
            temps_df = temps_df[swap_team_columns(colnames_all)]
        temps_df.columns = colnames_all
        all_per_game_df = pd.concat([all_per_game_df, temps_df])
all_per_game_df.drop(["fp_p"+str(i) for i in range(2,15)], axis=1)
# Out:
#       player_id_p1 player_id_p2 player_id_p3 player_id_p4 player_id_p5  \
# 0        robinna01    horfoal01    johnsjo02    chandwi01    smithjo03
# 1        bryanko01    hawessp01    udrihbe01    gasolpa01    casspom01
# 2        flynnjo01    howardw01    anderry01    nelsoja01    lewisra02
# 3        wallara01     boshch01    allenra02    allento01    turkohe01
# 4        howardw01    anderry01    nelsoja01    lewisra02    barnema02
# 5        flynnjo01    jeffeal01     loveke01    ellinwa01    wilkida02
# 6         wadedw01    jacksst02    richaqu01    wallage01    hasleud01
# 7        westbru01    duranke01    bogutan01     reddmi01    maynoer01
# 8        jamesle01    harride01    lopezbr01    jianlyi01    varejan01
# 9         paulch01    arizatr01    okafoem01    hayesch01    lowryky01
# 10        nashst01     mayooj01    stoudam01    amundlo01      gayru01
# 11         roybr01    webstma02    ellismo01    millean02    randoan01
# 12       hawessp01    udrihbe01    casspom01    thompja02    nowitdi01
# 13       hilarne01    lawsoty01     okurme01    boozeca01    martike01
# 14       jamisan01    arenagi01    duncati01    masonro01    butleca01
# 15       jacksst02    jamesle01    wallage01    varejan01    onealsh01
# 16       hilarne01    lawsoty01    martike01    afflaar01    smithjr01
# 17       bryanko01    nowitdi01     odomla01    bynuman01    goodedr01
# 18       chandwi01    hibbero01     headlu01    gallida01    dunlemi02
# 19        boshch01    duncati01    masonro01     jackja01    bargnan01
# 20       westbru01    duranke01     rosede01     denglu01    gibsota01
# 21         roybr01    webstma02    millean02    howarju01    cunnida01
# 22        wadedw01    horfoal01    johnsjo02    smithjo03    richaqu01
# 23        paulch01     okurme01    boozeca01    okafoem01    willide01
# 24       jacksst02     rosede01    wallage01     denglu01    hinriki01
# 25        kiddja01    nowitdi01    terryja01    goodedr01    howarjo01
# 26       hilarne01    lawsoty01    ellismo01    martike01    randoan01
# 27       barnema02    howardw01    hibbero01     headlu01    nelsoja01
# 28       bryanko01    farmajo01     odomla01    arizatr01    hayesch01
# 29       bogutan01    harride01    lopezbr01    jianlyi01    ilyaser01
# ...            ...          ...          ...          ...          ...
# 12575    fournev01     netora01     rosste01    augusdj01    fultzma01
# 12576    gasolma01    hezonma01    powelno01    simonan01    bazemke01
# 12577     nunnke01    clarkjo01    robindu01    garlada01    nancela02
# 12578    millspa01    allenja01    harriga01    morrimo01    grantje01
# 12579     dunnkr01     hillge01    whiteco01    youngth01    connapa01
# 12580    mcgruro01    jacksfr01    zubaciv01    mooreet01    harklma01
# 12581    marjabo01    smithde03    robinmi01    portibo01    hardati02
# 12582    saricda01    reddica01    huntede01    bridgmi01      lenal01
# 12583     monkma01    morrima02    gallola01    zelleco01    washipj01
# 12584    greendr01    robingl02    kanteen01    theisda01    caulewi01
# 12585    mcderdo01    holidju01    mccontj01    mclembe01    riverau01
# 12586    caldwke01    howardw01    kuzmaky01    greenda02    josepco01
# 12587    valanjo01    conlemi01    anderky01    jonesty01    inglejo01
# 12588    okogijo01    thomais02    browntr01    wagnemo01    mcraejo01
# 12589    harrito02    gilgesh01    adamsst01     noelne01    korkmfu01
# 12590    augusdj01     rosste01    forbebr01    fultzma01    lylestr01
# 12591    allenja01    markkla01     dunnkr01    harrijo01    hutchch01
# 12592    klebima01    brunsja01    curryse01    powelno01    wrighde01
# 12593    lopezbr01    holidaa01    mcderdo01    brownst02    holidju01
# 12594    harklma01    zubaciv01    jonesda03    robinje01    turneev01
# 12595    herroty01    olynyke01    mellini01    mooreet01    robindu01
# 12596    vonleno01    mclembe01    culveja01    grahatr01    riverau01
# 12597    zelleco01    washipj01    gibsota01    robinmi01    batumni01
# 12598    hezonma01    forbebr01    millspa02    poeltja01    whitede01
# 12599    horfoal01    garlada01    clarkjo01    osmande01    ennisja01
# 12600    crabbal01    kuzmaky01    howardw01    jonesda03    reddica01
# 12601    anderky01    clarkbr01    morrimo01    grantje01    meltode01
# 12602    mooreet01    mellini01    bowmaky01    caulewi01    robingl02
# 12603    milescj01     rosste01    thomais02    augusdj01    fultzma01
# 12604    bjeline01    holmeri01    kanteen01    theisda01    gilesha01
#
#       player_id_p6 player_id_p7 player_id_p8 player_id_p9 player_id_p10  ...  \
# 0        bibbymi01    gallida01    harrial01      leeda02     duhonch01  ...
# 1         odomla01    bynuman01    udokaim01    fishede01     rodrise01  ...
# 2        barnema02    cartevi01    jeffeal01     loveke01     ellinwa01  ...
# 3         jackja01    bargnan01    perkike01    houseed01     davisgl01  ...
# 4        cartevi01     rosede01     denglu01    gibsota01     salmojo01  ...
# 5        hibbero01     headlu01    watsoea01    mcrobjo01     dunlemi02  ...
# 6         diawbo01    augusdj01    feltora01    beaslmi01     onealje01  ...
# 7        ilyaser01    jennibr01    warriha01    sefolth01     ridnolu01  ...
# 8        onealsh01    douglch01    willima01    parkean01       leeco01  ...
# 9        brookaa01     westda01    battish01    brownde02     scolalu01  ...
# 10       randoza01    youngsa01    gasolma01    tinslja01     conlemi01  ...
# 11       maggeco01    howarju01    cunnida01    morroan01     curryst01  ...
# 12        kiddja01    goodedr01    evansty01    greendo01     terryja01  ...
# 13       willide01    afflaar01    smithjr01    millspa01     brewero02  ...
# 14       parketo01    blatcan01    jefferi01    ginobma01     boganke01  ...
# 15       willima01     diawbo01    augusdj01    feltora01     parkean01  ...
# 16       cartean01    brandel01    iversal01    carnero01     youngth01  ...
# 17       bareajo01    mariosh01    brownsh01    vujacsa01     farmajo01  ...
# 18        rushbr01    jonesda02    harrial01      leeda02     duhonch01  ...
# 19       parketo01    jefferi01    ginobma01    boganke01     banksma01  ...
# 20       maynoer01    salmojo01    hinriki01    sefolth01     collini01  ...
# 21       bayleje01    pendeje02    cambyma01    davisba01     kamanch01  ...
# 22       bibbymi01    hasleud01    beaslmi01    willima02     crawfja01  ...
# 23        westda01    millspa01    brewero02    kirilan01     brownde02  ...
# 24       gibsota01    feltora01     noahjo01    murraro01     thomaty01  ...
# 25       bareajo01    mariosh01    villach01    stuckro01     hamilri01  ...
# 26       maggeco01    afflaar01    smithjr01    morroan01     cartean01  ...
# 27       watsoea01    lewisra02    dunlemi02    jonesda02      rushbr01  ...
# 28       bynuman01    lowryky01    brookaa01    battish01     fishede01  ...
# 29       jennibr01    douglch01    warriha01    ridnolu01     mbahalu01  ...
# ...            ...          ...          ...          ...           ...  ...
# 12575    ennisja01    oquinky01    vucevni01    horfoal01     simmobe01  ...
# 12576    holliro01    daviste02    lillada01    siakapa01     vanvlfr01  ...
# 12577    osmande01    porteke02    butleji01     loveke01     leoname01  ...
# 12578    plumlma01     musadz01    irvinky01    jokicni01     bartowi01  ...
# 12579    matthwe02    korveky01    antetgi01    bledser01     lavinza01  ...
# 12580    hayesja02     mannte01    georgpa01    willilo02     holidjr01  ...
# 12581    wrighde01    finnedo01    doncilu01    morrima03     porzikr01  ...
# 12582    bembrde01    jonesda03    youngtr01    rubiori01     bookede01  ...
# 12583    martico01    willima02    grahade01    drumman01     kennalu01  ...
# 12584    spellom01    wanambr01    russeda01    walkeke02     tatumja01  ...
# 12585    chandty01    sefolth01    hardeja01    sabondo01     westbru01  ...
# 12586    ferreyo01    carusal01    davisan02    jamesle01     bogdabo01  ...
# 12587    onealro01    mudiaem01    mitchdo01    goberru01     brookdi01  ...
# 12588    culveja01    grahatr01    townska01     bealbr01     dienggo01  ...
# 12589    scottmi01    fergute01    embiijo01    simmobe01      paulch01  ...
# 12590    poeltja01    aminual01    vucevni01    derozde01     aldrila01  ...
# 12591    templga01     musadz01    lavinza01    princta02     dinwisp01  ...
# 12592    finnedo01    thomama02    doncilu01    siakapa01     vanvlfr01  ...
# 12593    matthwe02    lopezro01    antetgi01    bledser01     sabondo01  ...
# 12594    bembrde01     mannte01    youngtr01    georgpa01     willilo02  ...
# 12595    silvach01    hayesja02    holidjr01    butleji01     adebaba01  ...
